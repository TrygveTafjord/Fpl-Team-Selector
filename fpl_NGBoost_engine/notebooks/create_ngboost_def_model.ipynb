# %% [markdown]
# # Notebook for creating NGBoost models
#
# Feature selection is (somewhat) done in the feature selection notebook. However the only take away I could get was that having correlated features decreased model performance and than having a lot of features causes overfitting. The final features can be found in the "utils/fetch_data_for_NGBoost"
#
# On how to use NGBoost
# https://stanfordmlgroup.github.io/ngboost/intro.html

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from pathlib import Path
from ngboost import NGBRegressor
from sklearn.metrics import mean_squared_error
from ngboost.distns import LogNormal



# Add project root to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.fetch_training_data_for_NGBoost.def_ import fetch_def_data_for_NGBoost

# %% [markdown]
# Creating the model, and dooing some light hyperparameter tuning.

# %%
np.random.seed(42)

X_train = fetch_def_data_for_NGBoost(fetch_test_set=False)

y_train = X_train['total_points']
X_train = X_train.drop(columns=['total_points'])

X_test = fetch_def_data_for_NGBoost(fetch_test_set=True)
y_test = X_test['total_points']
X_test = X_test.drop(columns=['total_points'])

HAUL_THRESHOLD = 6      # A player performance of 8 points or more is a "haul".
WEIGHT_MULTIPLIER = 5   # Give these instances more importance during training.

# Create the sample_weights array
#sample_weights = np.ones(len(y_train))
#sample_weights[y_train >= HAUL_THRESHOLD] = WEIGHT_MULTIPLIER


ngb_def = NGBRegressor(verbose=True,         #Prits training progress
                       n_estimators=500,     # Number of boosting iterations
                       learning_rate=0.005, 
                       natural_gradient=True, 
                       minibatch_frac=0.7,
                       verbose_eval=100, 
                       early_stopping_rounds=12)

print("--- Training NGBoost Model for DEF ---")
ngb_def.fit(X_train, y_train)
print("--- Training Complete ---")

# Make predictions on the test set
y_preds = ngb_def.predict(X_test)
y_dists = ngb_def.pred_dist(X_test)

# Evaluate the model's performance
test_MSE = mean_squared_error(y_test, y_preds)

# Test Negative Log Likelihood (how well the predicted distributions match the actual outcomes)
test_NLL = -y_dists.logpdf(y_test.values).mean()

# Print the evaluation metrics
print(f"\n--- DEF Model Evaluation ---")
print(f'Test MSE: {test_MSE:.4f}') # Mean Squared Error
print(f'Test NLL: {test_NLL:.4f}') # Negative Log Likelihood (How likely is the true outcome given the predicted distribution)

print(f"\n--- DEF Evaluation On 20 highest scoring matches ---")
y_test_top20 = y_test.nlargest(20)
X_test_top20 = X_test.loc[y_test_top20.index]
y_preds_top20 = ngb_def.predict(X_test_top20)
top20_MSE = mean_squared_error(y_test_top20, y_preds_top20)
top20_NLL = -ngb_def.pred_dist(X_test_top20).logpdf(y_test_top20.values).mean()
print(f'Top 20 Test MSE: {top20_MSE:.4f}')
print(f'Top 20 Test NLL: {top20_NLL:.4f}')
# Out:
#                   name position      team   xP  assists  bps  clean_sheets  \
# 437    Aaron Cresswell      DEF  West Ham  1.3        0   16             0
# 1015   Aaron Cresswell      DEF  West Ham  2.0        0   14             0
# 1604   Aaron Cresswell      DEF  West Ham  1.0        0    6             0
# 2203   Aaron Cresswell      DEF  West Ham  2.2        0   26             1
# 2809   Aaron Cresswell      DEF  West Ham  1.7        0   16             0
# 3923   Aaron Cresswell      DEF  West Ham  2.5        0   13             0
# 4503   Aaron Cresswell      DEF  West Ham  3.5        0   21             1
# 5144   Aaron Cresswell      DEF  West Ham  3.0        0   20             0
# 5787   Aaron Cresswell      DEF  West Ham  3.0        0   19             0
# 6381   Aaron Cresswell      DEF  West Ham  0.0        0   23             0
# 7017   Aaron Cresswell      DEF  West Ham  4.5        0   33             1
# 7672   Aaron Cresswell      DEF  West Ham  3.7        0   15             0
# 8333   Aaron Cresswell      DEF  West Ham  3.2        0   12             0
# 8999   Aaron Cresswell      DEF  West Ham  3.0        0   19             0
# 9671   Aaron Cresswell      DEF  West Ham  0.2        0    7             0
# 10348  Aaron Cresswell      DEF  West Ham  1.0        0   17             0
# 11090  Aaron Cresswell      DEF  West Ham  1.0        0    3             0
# 11904  Aaron Cresswell      DEF  West Ham  1.2        0   15             0
# 15760  Aaron Cresswell      DEF  West Ham  0.2        0    4             0
# 19041  Aaron Cresswell      DEF  West Ham  0.6        0    3             0
#
#        expected_assists  expected_goal_involvements  expected_goals_conceded  \
# 437             0.00000                     0.00000                   0.0000
# 1015            0.00000                     0.00000                   0.0000
# 1604            0.00000                     0.00000                   0.0000
# 2203            0.00000                     0.00000                   0.0000
# 2809            0.00000                     0.00000                   0.0000
# 3923            0.00000                     0.00000                   0.0000
# 4503            0.00000                     0.00000                   0.0000
# 5144            0.00000                     0.00000                   0.0000
# 5787            0.00000                     0.00000                   0.0000
# 6381            0.00000                     0.00000                   0.0000
# 7017            0.00000                     0.00000                   0.0000
# 7672            0.00000                     0.00000                   0.0000
# 8333            0.00000                     0.00000                   0.0000
# 8999            0.20854                     0.20854                   1.7760
# 9671            0.00897                     0.00897                   2.1036
# 10348           0.06226                     0.09276                   1.6274
# 11090           0.00336                     0.00336                   0.6746
# 11904           0.09947                     0.13227                   0.8366
# 15760           0.13000                     0.13000                   0.3100
# 19041           0.00000                     0.00000                   0.0000
#
#        ...  team_h_score  total_points  value  was_home  yellow_cards  GW  \
# 437    ...             0             1     50      True             0   1
# 1015   ...             1             2     50     False             0   2
# 1604   ...             0             0     50      True             1   3
# 2203   ...             0             6     50     False             0   4
# 2809   ...             1             2     49      True             0   5
# 3923   ...             1             2     48     False             0   8
# 4503   ...             2             5     48      True             1   9
# 5144   ...             3             2     48      True             0  10
# 5787   ...             1             3     48     False             0  11
# 6381   ...             1             2     48     False             0  12
# 7017   ...             2             8     48      True             0  13
# 7672   ...             1             2     48     False             0  14
# 8333   ...             1             1     48      True             0  15
# 8999   ...             0             1     48      True             0  16
# 9671   ...             3             1     48     False             0  17
# 10348  ...             0             1     48      True             0  18
# 11090  ...             2             1     48     False             0  19
# 11904  ...             1             2     48     False             0  20
# 15760  ...             4             1     47      True             0  25
# 19041  ...             1             1     47      True             0  29
#
#         season  attack_strength_difference  defence_strength_difference  \
# 437    2022-23                      -235.0                       -280.0
# 1015   2022-23                       120.0                         45.0
# 1604   2022-23                       -55.0                        -90.0
# 2203   2022-23                        80.0                         40.0
# 2809   2022-23                       -85.0                       -150.0
# 3923   2022-23                       110.0                         40.0
# 4503   2022-23                        65.0                        -40.0
# 5144   2022-23                         5.0                         -5.0
# 5787   2022-23                        90.0                         40.0
# 6381   2022-23                      -110.0                        -70.0
# 7017   2022-23                        65.0                        -50.0
# 7672   2022-23                       -15.0                        -30.0
# 8333   2022-23                        55.0                        -50.0
# 8999   2022-23                        25.0                        -50.0
# 9671   2022-23                       -90.0                       -140.0
# 10348  2022-23                       -55.0                       -100.0
# 11090  2022-23                        20.0                         40.0
# 11904  2022-23                        90.0                         10.0
# 15760  2022-23                        40.0                        -40.0
# 19041  2022-23                        65.0                        -10.0
#
#        strength_difference
# 437                   -2.0
# 1015                   0.0
# 1604                   0.0
# 2203                   0.0
# 2809                   0.0
# 3923                   0.0
# 4503                   0.0
# 5144                   0.0
# 5787                   1.0
# 6381                  -1.0
# 7017                   1.0
# 7672                   0.0
# 8333                   0.0
# 8999                   0.0
# 9671                  -1.0
# 10348                  0.0
# 11090                  0.0
# 11904                  0.0
# 15760                  0.0
# 19041                  1.0
#
# [20 rows x 26 columns]
# c:\Users\trygt\fpl_dir\fpl_team_selector\utils\fetch_data_for_NGBoost\def_.py:18: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/2024-25/gws/merged_gw.csv", usecols=def_features)
#                     name position      team   xP  assists  bps  clean_sheets  \
# 1226     Aaron Cresswell      DEF  West Ham  0.5        0    3             0
# 3194     Aaron Cresswell      DEF  West Ham  0.5        0    3             0
# 4524     Aaron Cresswell      DEF  West Ham  1.0        0    2             0
# 5861     Aaron Cresswell      DEF  West Ham  0.3        0    1             0
# 9911     Aaron Cresswell      DEF  West Ham  0.2        0    5             0
# 12017    Aaron Cresswell      DEF  West Ham  0.8        0    5             0
# 14160    Aaron Cresswell      DEF  West Ham  0.4        0    3             0
# 802    Aaron Wan-Bissaka      DEF  West Ham  0.5        0    4             0
# 1433   Aaron Wan-Bissaka      DEF  West Ham -0.3        0    8             0
# 2082   Aaron Wan-Bissaka      DEF  West Ham  1.0        0    8             0
# 2741   Aaron Wan-Bissaka      DEF  West Ham  1.2        0    1             0
# 3403   Aaron Wan-Bissaka      DEF  West Ham  1.7        0    8             0
# 4067   Aaron Wan-Bissaka      DEF  West Ham  2.3        0   11             0
# 4733   Aaron Wan-Bissaka      DEF  West Ham  0.8        0   13             0
# 5401   Aaron Wan-Bissaka      DEF  West Ham  1.3        0    8             0
# 6073   Aaron Wan-Bissaka      DEF  West Ham  1.0        0    3             0
# 6747   Aaron Wan-Bissaka      DEF  West Ham  3.0        0   25             1
# 7427   Aaron Wan-Bissaka      DEF  West Ham  7.3        0   39             1
# 8112   Aaron Wan-Bissaka      DEF  West Ham  6.0        0   10             0
# 8803   Aaron Wan-Bissaka      DEF  West Ham  7.0        0    0             0
#
#        expected_assists  expected_goal_involvements  expected_goals_conceded  \
# 1226               0.00                        0.00                     0.03
# 3194               0.01                        0.01                     0.68
# 4524               0.00                        0.03                     0.13
# 5861               0.00                        0.00                     0.10
# 9911               0.06                        0.06                     0.17
# 12017              0.03                        0.03                     0.40
# 14160              0.00                        0.00                     0.78
# 802                0.00                        0.00                     0.56
# 1433               0.05                        0.05                     3.00
# 2082               0.03                        0.03                     1.54
# 2741               0.29                        0.29                     2.19
# 3403               0.06                        0.08                     0.37
# 4067               0.09                        0.11                     0.65
# 4733               0.02                        0.05                     1.92
# 5401               0.04                        0.04                     2.12
# 6073               0.03                        0.03                     2.17
# 6747               0.01                        0.01                     1.05
# 7427               0.01                        0.08                     1.69
# 8112               0.02                        0.47                     3.60
# 8803               0.20                        0.24                     1.67
#
#        ...  team_h_score  total_points  value  was_home  yellow_cards  GW  \
# 1226   ...             0             1     40     False           0.0   2
# 3194   ...             0             1     40      True           0.0   5
# 4524   ...             4             1     40      True           0.0   7
# 5861   ...             2             0     40      True           1.0   9
# 9911   ...             2             1     40      True           0.0  15
# 12017  ...             0             1     39     False           0.0  18
# 14160  ...             3             1     39      True           0.0  21
# 802    ...             0             1     45     False           0.0   2
# 1433   ...             1             1     45      True           0.0   3
# 2082   ...             1             2     45     False           0.0   4
# 2741   ...             0             1     45      True           0.0   5
# 3403   ...             1             2     45     False           0.0   6
# 4067   ...             4             2     45      True           0.0   7
# 4733   ...             4             0     45     False           0.0   8
# 5401   ...             2             2     44      True           0.0   9
# 6073   ...             3             1     44     False           0.0  10
# 6747   ...             0             6     44      True           0.0  11
# 7427   ...             0            15     44     False           0.0  12
# 8112   ...             2             6     44      True           0.0  13
# 8803   ...             3             1     45     False           0.0  14
#
#         season  attack_strength_difference  defence_strength_difference  \
# 1226   2024-25                       -80.0                        -50.0
# 3194   2024-25                      -210.0                        -80.0
# 4524   2024-25                         0.0                         50.0
# 5861   2024-25                       -50.0                        -40.0
# 9911   2024-25                       -80.0                        -30.0
# 12017  2024-25                       100.0                         90.0
# 14160  2024-25                       -70.0                        -60.0
# 802    2024-25                       -80.0                        -50.0
# 1433   2024-25                      -280.0                        -80.0
# 2082   2024-25                       -70.0                        -60.0
# 2741   2024-25                      -210.0                        -80.0
# 3403   2024-25                      -170.0                        -10.0
# 4067   2024-25                         0.0                         50.0
# 4733   2024-25                      -180.0                         20.0
# 5401   2024-25                       -50.0                        -40.0
# 6073   2024-25                      -160.0                       -240.0
# 6747   2024-25                       -40.0                        -70.0
# 7427   2024-25                      -250.0                        -80.0
# 8112   2024-25                      -210.0                       -310.0
# 8803   2024-25                       100.0                         70.0
#
#       strength_difference
# 1226                  0.0
# 3194                  0.0
# 4524                  1.0
# 5861                  0.0
# 9911                  0.0
# 12017                 1.0
# 14160                 0.0
# 802                   0.0
# 1433                 -1.0
# 2082                  0.0
# 2741                  0.0
# 3403                  0.0
# 4067                  1.0
# 4733                  0.0
# 5401                  0.0
# 6073                 -1.0
# 6747                  0.0
# 7427                 -1.0
# 8112                 -2.0
# 8803                  1.0
#
# [20 rows x 26 columns]
# --- Training NGBoost Model for DEF ---
# early_stopping_rounds is set to 12 but no validation set is provided creating val set with 0.1 of the training data
# Creating validation set without sample weight similar to the training data
# [iter 0] loss=2.4707 val_loss=2.5323 scale=1.0000 norm=2.3230
# [iter 100] loss=2.4185 val_loss=2.4919 scale=1.0000 norm=2.2570
# [iter 200] loss=2.3639 val_loss=2.4713 scale=2.0000 norm=4.3769
# [iter 300] loss=2.3308 val_loss=2.4647 scale=2.0000 norm=4.3003
# == Early stopping achieved.
# == Best iteration / VAL319 (val_loss=2.4642)
# --- Training Complete ---
#
# --- DEF Model Evaluation ---
# Test MSE: 6.8545
# Test NLL: 2.3489
#
# --- DEF Evaluation On 20 highest scoring matches ---
# Top 20 Test MSE: 123.4944
# Top 20 Test NLL: 9.5190

# %%
models_dir = Path('../models')
models_dir.mkdir(exist_ok=True)

file_path = models_dir / 'ngboost_def_model.pkl'

try:
    with open(file_path, "wb") as f:
        pickle.dump(ngb_def, f)
    print(f"Model successfully saved to: {file_path}")
except NameError:
    print("Error: The model object 'ngb_def' was not found.")
    print("Please make sure you have trained the model in a previous cell.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Model successfully saved to: ..\models\ngboost_def_model.pkl

# %% [markdown]
# Looking at the feature importance of different features for the final model

# %%
## Feature importance for loc trees
feature_importance_loc = ngb_def.feature_importances_[0]

## Feature importance for scale trees
feature_importance_scale = ngb_def.feature_importances_[1]

# %%
feature_names = X_train.columns

# Create a DataFrame for the 'loc' parameter importances
df_loc = pd.DataFrame({'feature': feature_names,
                       'importance': feature_importance_loc}) \
           .sort_values('importance', ascending=False)

# Create a DataFrame for the 'scale' parameter importances
df_scale = pd.DataFrame({'feature': feature_names,
                         'importance': feature_importance_scale}) \
             .sort_values('importance', ascending=False)

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(19, 8))
fig.suptitle("Feature Importance for Distribution Parameters", fontsize=17)

# Plot feature importance for the 'loc' parameter
sns.barplot(x='importance', y='feature', ax=ax1, data=df_loc.head(15), color="skyblue")
ax1.set_title('Location (Mean) Parameter Importance')
ax1.set_xlabel('Importance Score')
ax1.set_ylabel('Feature')

# Plot feature importance for the 'scale' parameter
sns.barplot(x='importance', y='feature', ax=ax2, data=df_scale.head(15), color="lightcoral")
ax2.set_title('Scale (Uncertainty) Parameter Importance')
ax2.set_xlabel('Importance Score')
ax2.set_ylabel('') # Hide y-axis label for clarity

# Improve layout and display the plot
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# #### Predictions vs Actuall points

# %%
# Plotting y_pred against y_test
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_preds, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # Diagonal line
plt.title('Predicted vs Actual Points for DEF')
plt.xlabel('Actual Points')
plt.ylabel('Predicted Points')
# Out:
# Text(0, 0.5, 'Predicted Points')

# %% [markdown]
# For the top 20 scoring players, looking at the predicted distribution

# %%
from scipy.stats import norm

# Ensure you have the trained model 'ngb_def', X_test, and y_test in your environment

# Get Top 20 Highest Scoring Instances from the Test Set ---
y_test_top20 = y_test.nlargest(20)
X_test_top20 = X_test.loc[y_test_top20.index]

# Get Predicted Distributions for these Top 20 Players ---
y_dists_top20 = ngb_def.pred_dist(X_test_top20)

# --- Plotting ---
plt.style.use('seaborn-v0_8-whitegrid')
fig, axes = plt.subplots(5, 4, figsize=(20, 22))
fig.suptitle('Predicted Point Distributions for Top 20 Actual', fontsize=20, y=1.02)
axes = axes.ravel() # Flatten the 5x4 grid into a 1D array

for i, (idx, y_actual) in enumerate(y_test_top20.items()):
    ax = axes[i]
    
    # Get the predicted distribution parameters (loc=mean, scale=std. dev. for Normal)
    loc = y_dists_top20.loc[i]
    scale = y_dists_top20.scale[i]
    
    # Generate points for the PDF curve
    x = np.linspace(loc - 4*scale, loc + 4*scale, 200)
    pdf = norm.pdf(x, loc=loc, scale=scale)
    
    # Plot the predicted distribution
    ax.plot(x, pdf, color='royalblue', label=f'Pred. Dist. (μ={loc:.1f}, σ={scale:.1f})')
    ax.fill_between(x, pdf, alpha=0.2, color='royalblue')
    
    # Mark the actual score with a vertical line
    ax.axvline(y_actual, color='red', linestyle='--', label=f'Actual Points: {y_actual:.0f}')
    
    ax.set_title(f'Player Instance {i+1}')
    ax.set_xlabel('Total Points')
    ax.set_ylabel('Probability Density')
    ax.legend()
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()
plt.show()

# %%
# Clean up variables to free memory
del X_train, y_train, X_test, y_test, y_preds, y_dists, y_test_top20, X_test_top20, y_dists_top20, df_loc, df_scale, models_dir, file_path, ngb_def
